# %% [markdown]
# # Machine Learning
#
# what is ML: algorithm ที่ืทำให้คอมพิวเตอร์เรียนรู้และสร้างกฎขึ้นมาเองจากข้อมูล
#
# What problems do ML suit with: ก้ปัญหาที่ซับซ้อนและมีข้อมูลเยอะเกินกว่าที่จะมานั่งเขียนโค้ดดักเงื่อนไขเองได้ทั้งหมด (Rule base not fit)
#
# ## requirements
# - no missing value

# %%
#from sklearn.{Module} import {classes,...}

# %% [markdown]
# ### Feature / indipendent variable

# %% [markdown]
# ### Target / dependent variable

# %% [markdown]
# ## Inferencce

# %% [markdown]
# ## Hyber parameter

# %% [markdown]
# ## Type of Supervised learning
#
# - Classification : Target variable is categories
# - Regresstion : Target variable is continus eg. temp, predict_score

# %% [markdown]
# ## KNN - K nearest neighbor
# concept: มองดูว่าใครอยู่ใกล้ที่สุดบ้าง k ลำดับแรก
# limitation:

# %%
from sklearn.neighbors import KNeighborsClassifier

#X = feature
#Y = targets
#print(X.shape, Y.shape) --> (Xrow, Xcol) (Yrow, Ycol)
knn = KNeighborsClassifier(n_neighbors=15) # create knn obj
#knn.fit(x, y)

#new_data = np....

#predictions = knn.predict(new_data) #-> try predict data

# %% [markdown]
# # Measuring mode performance
#
# ## Accuracy
# ตรงๆคำนวนง่ายๆ correct/total
#
# ## Computing accuracy
# data -- split data --> training/Test
# - แยกออกจากกันอย่างชัดเจน แบ่งจาก data เดียวกัน แบ่งกันอย่างชัดเจน no overlapse
# - Trainig set -- Fit/train on training set --> Inference with test set --> cal acc

# %%
from sklearn.model_selection import train_test_split
#x
#y
#x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=21, stratify=y)

# %% [markdown]
# ## Model complexity
# -> larger k = less complex model

# %% [markdown]
# ## Underfitting
#
# ## Overfitting

# %% [markdown]
# ## Class imbalance
#
# fixed?
# use confusion matrix true/falsr - positive/negative
#
# precision = true positive / all positive case(true positive + false positive)
# recall = true positive / false neative + true positive /
#
# F1 score
# precision * recall / precision + recall

# %% [markdown]
# # Regression model

# %%
from sklearn.linear_model import LinearRegression

#X
#y

reg = LinearRegression()
#reg.fit(X, y)
#predictions = reg.predict(X_bmi)

# %% [markdown]
# ## loss function
# -> evaluate ... by compare output with expect value

# %% [markdown]
# # Cross-Validation motivation
# instead of split data
#
# do this instead
#
# K-fold
#
# eg. k = 5

# %% [markdown]
# # Regularize
