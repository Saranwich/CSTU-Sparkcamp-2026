# %% [markdown]
# # Python import types
# ---
# - Implicit : import everything
# - Explicit : import just what we will use

# %%
import os #implicit
from tkinter import * #implicit
from math import sqrt #explicit
