# %% [markdown]
# # Python import types
# ---
# - Implicit
# - Explicit
# - Relavent

# %%
import sys
from collections import Counter
from datetime import datetime

# Explicit import

# Implicit import (using a module's functionality without direct reference)
data = Counter(['a', 'b', 'a', 'c', 'b', 'a'])

# Relevant import (importing what you actually need)
current_time = datetime.now()
print(current_time)

# %%
import os
from math import sqrt
